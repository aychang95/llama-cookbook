# %% [markdown]
# # Mathematical Operations Notebook
#
# This notebook demonstrates basic arithmetic operations in Python. Below, we'll explore simple addition operations and their results.
#
# ## Overview
#
# The following cells perform fundamental mathematical calculations, showcasing Python's built-in arithmetic capabilities for numerical computations.

# %%
5+5
# Out:
# 10

# %%
1+1
# Out:
# 2
